# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandocillo/EE400/blob/main/superficies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# Imagem (contour)
# Arranjo em superfície
x, y = np.meshgrid( np.linspace(-1.5, 1.5, 100),
                    np.linspace(-1.5, 1.5, 100))
z = x**2 + y**2

plt.figure(figsize=(8,6))
plt.gray()
plt.contourf(x,y,z, levels=20)
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(8,6))
ax = plt.axes(projection='3d')
ax.plot_wireframe(x, y, z)
plt.show()

# %%
Exercício 1
Objetivo: exercitar o uso do Teorema de Green
Use o Teorema de Green para encontrar a fórmula da área de uma circunferência de raio r.

A = 1/2 int (Fx dy - Fy dx)

x = r.cos(t)
y = r.sen(t)
dx = -r.sen(t) dt
dy = r.cos(t) dt

F= (x,y) = (r.cos(t), r.sen(t))

A = 1/2 int (r.cos(t).r.cos(t) - r.sen(t).(-r).sen(t))dt
A = 1/2 int (r^2)dt
A = 1/2 r^2 [2.pi - 0]
A = pi.r^2

# %%
Exercício 2
Objetivo: calcular a área de uma elipse usando o Teorema de Green
Parametrize uma elipse e encontre uma fórmula fechada para a sua área como uma função de seus
parâmetros. Gere uma figura mostrando sua elipse.

A = 1/2 int (Fx dy - Fy dx)

x = a.cos(t)
y = b.sen(t)
dx = -a.sen(t) dt
dy = b.cos(t) dt

F= (x,y) = (a.cos(t), b.sen(t))

A = 1/2 int (a.cos(t).b.cos(t) - b.sen(t)(-a).sen(t))dt
A = 1/2 a.b int (1) dt
A = 1/2 a.b 2.pi
A = a.b.pi

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0, 2*np.pi, 100)
a = 5
b = 3
x = a*np.cos(t)
y = b*np.sin(t)

plt.figure()
plt.plot(x,y)
plt.show()

# %%
Exercício 3
Objetivo: calcular o volume de um cone elíptico
Um cone elíptico pode ser gerado pela sobreposição de diversas elipses cada vez maiores.
a) Insira a variável z na fórmula que você encontrou no exercício 2 de forma a gerar elipses cuja
proporção varie linearmente no eixo z.
b) Faça um plot 3D de um cone elíptico de altura à sua escolha.
c) Encontre uma fórmula fechada para o volume de um cone elíptico de altura h.

# %%
a) z =np.sqrt((x/a)**2 + (y/b)**2)

# %%
#b)

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0, 2*np.pi, 100)
a = 5
b = 3
z =np.sqrt((x/a)**2 + (y/b)**2)

x, y = np.meshgrid(a*np.cos(np.linspace(0, 2*np.pi, 100)),
                   b*np.sin(np.linspace(0, 2*np.pi, 100)))

plt.figure()

ax = plt.axes(projection='3d')
ax.plot_wireframe(x, y, z)

plt.show()

# %%
#4

for N in np.linspace(4, 10, 7):
  t = np.linspace(0, 2*np.pi, 100)
  r = 2 + np.cos(N*t)
  x = r*np.cos(t)
  y = r*np.sin(t)

  plt.figure()
  plt.plot(x, y)
plt.show()

# %%
F = (x^2y^2 i)
r(t) = (x^2y^2, 0, 0)
r'(t)= (2xy^2, 0, 0)

int F(r(t))*|r'(t)| '= int  rot(F)

# %% [markdown]
# $\int\int\int$ p $dx dy dz$
#
# a) $\int \int \int$ 1 $dx dy dz$ = 1
#
# b)$\int \int \int$ $x^2$ $dx dy dz$ = $\int \int$ $\frac{x^3}{3}$ $dy dz$ \\
# $\int \int$ $\frac{1}{3}$ $dy dz$ = $\frac{1}{3}$
#
# c)$\int \int \int$ $x^2$ $dx dy dz$ = $\frac{1}{3}+\frac{1}{3}+\frac{1}{3}$ = 1
#
# d)$\int \int \int$ $xyz$ $dx dy dz$ = $\int \int \frac{x^2 yz}{2} dy dz$ \\
# $=\int \int \frac{yz}{2} dy dz$ = $\int \frac{y^2 z}{4} dz$ = $\int \frac{z}{4} dz$ \\
# $= \frac{z^2}{8}$ $= \frac{1}{8}$
